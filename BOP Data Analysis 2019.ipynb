# %%
# %matplotlib notebook 
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy
from scipy import stats
import seaborn as sns
sns.set()

# %%
data2018 = pd.read_csv('Z:/Documents/Data/___PACE/STEM-Summer2019/2018expeditions.csv', header=0)

# %%
# look at the first five rows
data2018.head()
# Out:
#                                           Unnamed: 0  \
# 0  Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                 Oil sheen present?\r\n(1=Yes,0=No)
# 2                           Oyster Measurements (mm)
# 3                                 Substrate Shell #1
# 4                                   Outer side photo
#
#   October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016  \
# 0                                                  3
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016  \
# 0                                                  4
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016  \
# 0                                                  6
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017  \
# 0                                                 2
# 1                                                 0
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017  \
# 0                                                4
# 1                                                0
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#   TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#                        ...                       \
# 0                      ...
# 1                      ...
# 2                      ...
# 3                      ...
# 4                      ...
#
#   TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017  \
# 0                                                  4
# 1                                                  1
# 2                                                NaN
# 3                                                NaN
# 4  http://s3-us-west-1.amazonaws.com/digital-plat...
#
#   Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  \
# 0                                                  2
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017  \
# 0                                                  5
# 1                                                  0
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Test\r\nBOP Pier 101,\r\nSeptember 12, 2017  \
# 0                                         NaN
# 1                                           0
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#   Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017  \
# 0                                              4
# 1                                              1
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#   No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   test 3\r\nPier 101,\r\nDecember 7, 2017  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017  \
# 0                                            1
# 1                                            0
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
#
#   Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018
# 0                                           3.0
# 1                                           0.0
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
# [5 rows x 22 columns]

# %%
# Display the column names
data2018.columns
# Out:
# Index(['Unnamed: 0',
#        'October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016',
#        'ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016',
#        'TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016',
#        'TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016',
#        'Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016',
#        '789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016',
#        'Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017',
#        'Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017',
#        'TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017',
#        'TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\r\nApril 20, 2017',
#        'Sherman Creek 3\r\nSherman Creek South,\r\nApril 21, 2017',
#        'TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017',
#        'Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017',
#        'Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017',
#        'Test\r\nBOP Pier 101,\r\nSeptember 12, 2017',
#        'Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017',
#        'No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017',
#        'test 3\r\nPier 101,\r\nDecember 7, 2017',
#        'Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017',
#        'Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017',
#        'SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018'],
#       dtype='object')

# %%
# look at the last five rows
data2018.tail()
# Out:
#     Unnamed: 0 October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016  \
# 220      Label                                                NaN
# 221     Method                                                NaN
# 222       Unit                                                NaN
# 223    Results                                                NaN
# 224    Average                                                NaN
#
#     ISLA 601\r\nSherman Creek South,\r\nOctober 21, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNovember 9, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNovember 16, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Sherman Creek Park 2\r\nSherman Creek South,\r\nDecember 2, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     789 Monitoring Kaiser Site at 22nd street\r\nIS 288 ORS,\r\nDecember 9, 2016  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017  \
# 220                                               NaN
# 221                                               NaN
# 222                                               NaN
# 223                                               NaN
# 224                                               NaN
#
#     Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017  \
# 220                                              NaN
# 221                                              NaN
# 222                                              NaN
# 223                                              NaN
# 224                                              NaN
#
#     TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\r\nApril 6, 2017  \
# 220                                          Phosphate
# 221                                        test strips
# 222                                                ppm
# 223                                              5,5,5
# 224                                                  5
#
#                          ...                       \
# 220                      ...
# 221                      ...
# 222                      ...
# 223                      ...
# 224                      ...
#
#     TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS,\r\nMay 10, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Sherman Creek 4\r\nSherman Creek South,\r\nMay 30, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     Test\r\nBOP Pier 101,\r\nSeptember 12, 2017  \
# 220                                         NaN
# 221                                         NaN
# 222                                         NaN
# 223                                         NaN
# 224                                         NaN
#
#     Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017  \
# 220                                            NaN
# 221                                            NaN
# 222                                            NaN
# 223                                            NaN
# 224                                            NaN
#
#     No-Admin Test Expedition 2\r\nPier 101,\r\nNovember 30, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     test 3\r\nPier 101,\r\nDecember 7, 2017  \
# 220                                     NaN
# 221                                     NaN
# 222                                     NaN
# 223                                     NaN
# 224                                     NaN
#
#     Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017  \
# 220                                          NaN
# 221                                          NaN
# 222                                          NaN
# 223                                          NaN
# 224                                          NaN
#
#     Test for Maintenance\r\nBOP Test Station,\r\nDecember 26, 2017  \
# 220                                                NaN
# 221                                                NaN
# 222                                                NaN
# 223                                                NaN
# 224                                                NaN
#
#     SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018
# 220                                           NaN
# 221                                           NaN
# 222                                           NaN
# 223                                           NaN
# 224                                           NaN
#
# [5 rows x 22 columns]

# %%
# transpose the data -- interchange rows and columns
data2018 = data2018.T

# %%
data2018.head()
# Out:
#                                                                                                   0    \
# Unnamed: 0                                          Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                  3
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                  4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                  4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                  6
#
#                                                                                    1    \
# Unnamed: 0                                          Oil sheen present?\r\n(1=Yes,0=No)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                   0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                   1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                   0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                   0
#
#                                                                          2    \
# Unnamed: 0                                          Oyster Measurements (mm)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                       NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                       NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
#
#                                                                    3    \
# Unnamed: 0                                          Substrate Shell #1
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                 NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                 NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
#
#                                                                  4    \
# Unnamed: 0                                          Outer side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...               NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...               NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...               NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...               NaN
#
#                                                                  5    \
# Unnamed: 0                                          Inner side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...               NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...               NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...               NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...               NaN
#
#                                                           6    \
# Unnamed: 0                                           Set date
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  7/14/2015
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  11/9/2016
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
#
#                                                                      7    \
# Unnamed: 0                                                        Source
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  Muscongus Bay, Maine
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          Harlem River
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
#
#                                                                                          8    \
# Unnamed: 0                                          Total number of live oysters at baseline
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                         0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                        12
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         4
#
#                                                                                            9    \
# Unnamed: 0                                          Total mass of live oysters at baseline (g)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                           0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                           2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
#
#                                                      ...        215   216  \
# Unnamed: 0                                           ...     Method  Unit
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   ...        NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   ...        NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   ...        NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   ...        NaN   NaN
#
#                                                         217      218    219  \
# Unnamed: 0                                          Results  Average  Other
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...      NaN      NaN    NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...      NaN      NaN    NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN    NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN    NaN
#
#                                                       220     221   222  \
# Unnamed: 0                                          Label  Method  Unit
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...    NaN     NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...    NaN     NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...    NaN     NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...    NaN     NaN   NaN
#
#                                                         223      224
# Unnamed: 0                                          Results  Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...      NaN      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...      NaN      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
#
# [5 rows x 225 columns]

# %%
data2018.iloc[0]
# Out:
# 0      Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# 1                     Oil sheen present?\r\n(1=Yes,0=No)
# 2                               Oyster Measurements (mm)
# 3                                     Substrate Shell #1
# 4                                       Outer side photo
# 5                                       Inner side photo
# 6                                               Set date
# 7                                                 Source
# 8               Total number of live oysters at baseline
# 9             Total mass of live oysters at baseline (g)
# 10                 Total number of live oysters on shell
# 11     Total mass of scrubbed substrate shell + oyste...
# 12                                     Measurements (mm)
# 13                     Minimum size of live oysters (mm)
# 14                     Maximum size of live oysters (mm)
# 15                     Average size of live oysters (mm)
# 16                                    Substrate Shell #2
# 17                                      Outer side photo
# 18                                      Inner side photo
# 19                                              Set date
# 20                                                Source
# 21              Total number of live oysters at baseline
# 22            Total mass of live oysters at baseline (g)
# 23                 Total number of live oysters on shell
# 24     Total mass of scrubbed substrate shell + oyste...
# 25                                     Measurements (mm)
# 26                     Minimum size of live oysters (mm)
# 27                     Maximum size of live oysters (mm)
# 28                     Average size of live oysters (mm)
# 29                                    Substrate Shell #3
#                              ...
# 195                                               Method
# 196                                                 Unit
# 197                                              Results
# 198                                              Average
# 199                                                   pH
# 200                                               Method
# 201                                                 Unit
# 202                                              Results
# 203                                              Average
# 204                                            Turbidity
# 205                                               Method
# 206                                                 Unit
# 207                                              Results
# 208                                              Average
# 209                                              Ammonia
# 210                                               Method
# 211                                                 Unit
# 212                                              Results
# 213                                              Average
# 214                                             Nitrates
# 215                                               Method
# 216                                                 Unit
# 217                                              Results
# 218                                              Average
# 219                                                Other
# 220                                                Label
# 221                                               Method
# 222                                                 Unit
# 223                                              Results
# 224                                              Average
# Name: Unnamed: 0, Length: 225, dtype: object

# %%
# change the column names to the names in the first row  instead of 1, 2, ... 
data2018.columns = data2018.iloc[0]

# %%
data2018.head()
# Out:
# Unnamed: 0                                         Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)  \
# Unnamed: 0                                          Water color\r\n(1=Light Blue,2=Dark Blue,3=Lig...
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                  3
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                  4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                  4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                  6
#
# Unnamed: 0                                          Oil sheen present?\r\n(1=Yes,0=No)  \
# Unnamed: 0                                          Oil sheen present?\r\n(1=Yes,0=No)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                   0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                   1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                   0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                   0
#
# Unnamed: 0                                          Oyster Measurements (mm)  \
# Unnamed: 0                                          Oyster Measurements (mm)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                       NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                       NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                       NaN
#
# Unnamed: 0                                          Substrate Shell #1  \
# Unnamed: 0                                          Substrate Shell #1
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                 NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                 NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                 NaN
#
# Unnamed: 0                                          Outer side photo  \
# Unnamed: 0                                          Outer side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...               NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...               NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...               NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...               NaN
#
# Unnamed: 0                                          Inner side photo  \
# Unnamed: 0                                          Inner side photo
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...               NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...               NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...               NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...               NaN
#
# Unnamed: 0                                           Set date  \
# Unnamed: 0                                           Set date
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  7/14/2015
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  11/9/2016
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
#
# Unnamed: 0                                                        Source  \
# Unnamed: 0                                                        Source
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  Muscongus Bay, Maine
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          Harlem River
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
#
# Unnamed: 0                                          Total number of live oysters at baseline  \
# Unnamed: 0                                          Total number of live oysters at baseline
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                         0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                        12
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         4
#
# Unnamed: 0                                          Total mass of live oysters at baseline (g)  \
# Unnamed: 0                                          Total mass of live oysters at baseline (g)
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                           0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                           2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                         3.8
#
# Unnamed: 0                                           ...     Method  Unit  \
# Unnamed: 0                                           ...     Method  Unit
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   ...        NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   ...        NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   ...        NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   ...        NaN   NaN
#
# Unnamed: 0                                          Results  Average  Other  \
# Unnamed: 0                                          Results  Average  Other
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...      NaN      NaN    NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...      NaN      NaN    NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN    NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN    NaN
#
# Unnamed: 0                                          Label  Method  Unit  \
# Unnamed: 0                                          Label  Method  Unit
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...    NaN     NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...    NaN     NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...    NaN     NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...    NaN     NaN   NaN
#
# Unnamed: 0                                          Results  Average
# Unnamed: 0                                          Results  Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...      NaN      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...      NaN      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...      NaN      NaN
#
# [5 rows x 225 columns]

# %%
# since the first row of the transposed data contains the variable names and not data, drop the first row
data2018 = data2018.drop(data2018.index[0])

# %%
# take a look and make sure you got what you wanted
data2018.head()
# Out:
# Unnamed: 0                                         Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                  3
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                  4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                  4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                  6
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                  6
#
# Unnamed: 0                                         Oil sheen present?\r\n(1=Yes,0=No)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                  0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                  1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                  0
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                  0
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                  0
#
# Unnamed: 0                                         Oyster Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                      NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                      NaN
#
# Unnamed: 0                                         Substrate Shell #1  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                NaN
#
# Unnamed: 0                                         Outer side photo  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...              NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...              NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...              NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...              NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...              NaN
#
# Unnamed: 0                                                                           Inner side photo  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                                NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  http://s3-us-west-1.amazonaws.com/digital-plat...
#
# Unnamed: 0                                           Set date  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  7/14/2015
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  11/9/2016
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  7/31/2015
# Sherman Creek Park 2\r\nSherman Creek South,\r\...  11/9/2016
#
# Unnamed: 0                                                        Source  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...  Muscongus Bay, Maine
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          Harlem River
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...  Muscongus Bay, Maine
# Sherman Creek Park 2\r\nSherman Creek South,\r\...          Harlem River
#
# Unnamed: 0                                         Total number of live oysters at baseline  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                        0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                       12
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                        4
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                        4
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                       12
#
# Unnamed: 0                                         Total mass of live oysters at baseline (g)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                          0
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                                          2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                        3.8
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                        3.8
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                          2
#
# Unnamed: 0                                           ...   Method Unit  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   ...      NaN  NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   ...      NaN  NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   ...      NaN  NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   ...      NaN  NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   ...      NaN  NaN
#
# Unnamed: 0                                         Results Average Other  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...     NaN     NaN   NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...     NaN     NaN   NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...     NaN     NaN   NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...     NaN     NaN   NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...     NaN     NaN   NaN
#
# Unnamed: 0                                         Label Method Unit Results  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...   NaN    NaN  NaN     NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...   NaN    NaN  NaN     NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...   NaN    NaN  NaN     NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...   NaN    NaN  NaN     NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...   NaN    NaN  NaN     NaN
#
# Unnamed: 0                                         Average
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...     NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...     NaN
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...     NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...     NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...     NaN
#
# [5 rows x 225 columns]

# %%
data2018.shape
# Out:
# (21, 225)

# %%
# you can print all the variable names
for i in range(len(data2018.columns)):
    print(data2018.columns[i])
# Out:
# Water color
# (1=Light Blue,2=Dark Blue,3=Light Green,
# 4=Dark Green,5=Light Brown,6=Dark Brown)
# Oil sheen present?
# (1=Yes,0=No)
# Oyster Measurements (mm)
# Substrate Shell #1
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #2
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #3
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #4
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #5
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #6
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #7
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #8
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #9
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Substrate Shell #10
# Outer side photo
# Inner side photo
# Set date
# Source
# Total number of live oysters at baseline
# Total mass of live oysters at baseline (g)
# Total number of live oysters on shell
# Total mass of scrubbed substrate shell + oysters + tag (g)
# Measurements (mm)
# Minimum size of live oysters (mm)
# Maximum size of live oysters (mm)
# Average size of live oysters (mm)
# Minimum size of all live oysters (mm)
# Maximum size of all live oysters (mm)
# Average size of all live oysters (mm)
# Total number of all live oysters
# Water Quality Sample #1
# Depth (m)
# Location (coordinates)
# Water Temperature
# Method
# Unit
# Results
# Average
# Dissolved Oxygen
# Method
# Unit
# Results
# Average
# Salinity
# Method
# Unit
# Results
# Average
# pH
# Method
# Unit
# Results
# Average
# Turbidity
# Method
# Unit
# Results
# Average
# Ammonia
# Method
# Unit
# Results
# Average
# Nitrates
# Method
# Unit
# Results
# Average
# Other
# Label
# Method
# Unit
# Results
# Average
# Water Quality Sample #2
# Depth (m)
# Location (coordinates)
# Water Temperature
# Method
# Unit
# Results
# Average
# Dissolved Oxygen
# Method
# Unit
# Results
# Average
# Salinity
# Method
# Unit
# Results
# Average
# pH
# Method
# Unit
# Results
# Average
# Turbidity
# Method
# Unit
# Results
# Average
# Ammonia
# Method
# Unit
# Results
# Average
# Nitrates
# Method
# Unit
# Results
# Average
# Other
# Label
# Method
# Unit
# Results
# Average

# %%
# you can explore specific subsets of the data
# "Oil sheen present? (1=Yes,0=No)" is the second column so we can extract it via implicit indexing
# Remember  Python indexing is zero based
for i in range(3):
    print(data2018.iloc[i, 1])
# Out:
# 0
# 1
# 0

# %%
# Display the measuremts for all substrates for the second expedition
data2018.iloc[0]["Measurements (mm)"]
# Out:
# Measurements (mm)    80,5.9
# Measurements (mm)       NaN
# Measurements (mm)        56
# Measurements (mm)        64
# Measurements (mm)       NaN
# Measurements (mm)       NaN
# Measurements (mm)       6.1
# Measurements (mm)        64
# Measurements (mm)        70
# Measurements (mm)       NaN
# Name: October Oyster Monitoring\r\nIS 288 ORS,\r\nOctober 13, 2016, dtype: object

# %%
# You can select multiple columns by using an array as the index
data2018[["Measurements (mm)", "Total number of all live oysters"]]
# Out:
# Unnamed: 0                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                             80,5.9
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  3.2,6.2,0.3,0.4,2.5,3.4,2,3.2,1.5
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                           20,26,17
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                              70,60
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                  70
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                72,87
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                  42,35,35,45,35,25
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            44,36,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                        6,5.2,4.2,3
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   30,30,50,40,30.5
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                              81,75
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...        4.1,3.5,3.6,4.2,5.5,3.3,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                      5,10
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      8
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                1,2
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         88,75
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                   105,88
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                     NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                      NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    1.5,3.4,1.3,2.3,2.2,2
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              25,23,22,21
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     86,69
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                        NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                              35,18,32,53
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                        41,34,37,40,25,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5.2,4.5,5.1,3.5,3.5,3.2,5.5,5.1,5.3,4.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                            10,40.5,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                      NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    4,4.6,5.2,5.6,4.8,3.6,3.5,5.1,4.5,2.3
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                         15,6
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 115
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 56
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                          1.3,3.4,1,2.4,1.7,3.7,0.9
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                 70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,20,15,18,15,16,18,25,18,16,18,17,20,18,12,2...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  15.1,10.1,14.6,18.6,16,16,15.4,21.1,21.1,18.6,...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.6,3.3,4.3,3.2,3.5,6.2,5.1,3.6,5,3.5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...             10,10,10,20,15,15,20,20,21,25,25,30,20
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                              3,2.1,3.1,1.9,3.7,2.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                               7,8.5,12
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                 64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                              2.4,3.1,2,1.5,2.7,1.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                              99999
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                              80,70
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                               57,83
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                   75
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  28,23,20,20,20,20,15,21,18,8,18,15,17,13,16,20...
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  29,16,21,7,9,18,2,25,27,26,8,9,5,16,19,13,20,3...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...              5.7,4.5,4.9,2.8,7,3.2,4.8,4.5,4.5,2.9
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  3,3,4,5,5,10,10,10,10,15,10,10,25,25,25,30,32,...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                 73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              2,3.9,4.4,2.1,3.5,4.2,3.4,3.5,5.6,4.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                                              Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                    NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                  3,2.1,3.1,1.9,3.7,2.7
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                    NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                    NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                    NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                     NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                      NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                26,20,38,27,30,28,41,40
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                                     35
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  6.6,5.3,3.4,3,3.4,4.5,5.2,4.3,5.2,6.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                         35,20,30,45,27
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                    NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...    3.6,4.4,2.6,4.3,4.2,4,3.4,3,3.6,2.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                           NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                        NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                    NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                               NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                          NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                    NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                         NaN
#
# Unnamed: 0                                                            Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                  NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...           2,3.12,4.4,2.1,3.5,4.2,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                  NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                  NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                75,64
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                    64
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                    NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...  20,15,18,18,21,14,25,28,12,25,30,15
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                 20,25,20,30,15,13,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...    3.3,4.5,6,1.8,0.5,6.9,1,5.8,5.9,4
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...          22,19,15,27,22,4,3,15,15,16
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                   60
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  4.6,4.8,2.6,6,3.3,3.7,4.9,5,2.9,3.5
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                         NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                      NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                  NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                             NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                        NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                  NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                       NaN
#
# Unnamed: 0                                                                    Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                          6.1
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.7,3.8,2,4,2.13,3.5,1,4.04,2.1,3.9,4.7,3.4
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                          NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                          NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                           65
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                           NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                          37,68
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                            35,18,42,35,40,36
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                               30,40,30,41,25
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...            2.4,7.8,2,2.9,4.7,3.5,4.7,6,3,4.7
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                               25,30,32,35,43
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                           64
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6.5,5.2,3.4,5.7,3.2,4.3,6.6,6.7
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                 NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                              NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                          NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                     NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                          NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                               NaN
#
# Unnamed: 0                                                                Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                       64
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...          3.2,3.01,4,2.04,1.09,1.07,2,1,1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                      NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                      NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                      NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                        80
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                         79
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                           58,30,34,28,37
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                            60,28,20,25,5
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                    4.6,7,2.7,3.3,3,3.1,5
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                           10,15,25,40,45
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                       73
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  5.5,4.5,3.2,3.2,2.6,3.6,3.4,4.3,5.1,5.2
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                             NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                          NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                      NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                 NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                            NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                      NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                           NaN
#
# Unnamed: 0                                                        Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                               70
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...  4.1,1.4,2.2,3.4,1.2,3.2,2.3,3.3
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                              NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                              NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                               81
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                66
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                 30
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                   35,23,28,53,32
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...    25.3,14.1,46.6,31.6,26.3,26.1
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...      3,3.7,1,2.4,8.6,2,3.5,7,4,6
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                   15,20,20,25,40
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                               80
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...  6.7,3.8,5.1,3.5,3.9,6.5,2.7,3.4
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                     NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                  NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                              NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                         NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                    115
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                              NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                   NaN
#
# Unnamed: 0                                                                          Measurements (mm)  \
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                                NaN
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                    5.6,4.4,5.6,2.5,3.2,2.4,3.5,2.1
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                                NaN
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                                NaN
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                                NaN
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                                 NaN
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                                  NaN
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...          23,27,20,18,22,30,35,16,26,32,23,18,18,21
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...  14,30,10,21,10,19,18,22,30,26,17,15,10,10,20,1...
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...  5,6.4,1.5,6.1,3.5,2.5,3.4,2.4,6,5.5,1.5,5.3,3....
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...  10,10,15,20,20,30,25,25,35,30,35,35,35,40,35,4...
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                                NaN
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...              6,4.4,2.9,4.1,3.5,4.2,5.6,6.4,4.1,7.1
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                                       NaN
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                                    NaN
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                                                NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                                           NaN
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                                      NaN
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                                                NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                                     NaN
#
# Unnamed: 0                                         Total number of all live oysters
# October Oyster Monitoring\r\nIS 288 ORS,\r\nOct...                                7
# ISLA 601\r\nSherman Creek South,\r\nOctober 21,...                               78
# TYWLS Expedition 1\r\nAstoria TYWLS ORS,\r\nNov...                                2
# TYWLS Expedition 2\r\nAstoria TYWLS ORS,\r\nNov...                                3
# Sherman Creek Park 2\r\nSherman Creek South,\r\...                                7
# 789 Monitoring Kaiser Site at 22nd street\r\nIS...                                9
# Cold Cold Cold\r\nIS 288 ORS,\r\nJanuary 27, 2017                                 8
# Eels and Shrimp\r\nIS 288 ORS,\r\nMarch 21, 2017                                  7
# TYWLS Expedition 3 (6-1)\r\nAstoria TYWLS ORS,\...                              102
# TYWLS Expedition 4 (7-2)\r\nAstoria TYWLS ORS,\...                              101
# Sherman Creek 3\r\nSherman Creek South,\r\nApri...                               96
# TYWLS Expedition 5 (7 - 1)\r\nAstoria TYWLS ORS...                              100
# Shooting Stars Week\r\nIS 288 ORS,\r\nMay 19, 2017                                7
# Sherman Creek 4\r\nSherman Creek South,\r\nMay ...                               89
# Test\r\nBOP Pier 101,\r\nSeptember 12, 2017                                       2
# Weirdy Fish\r\nIS 288 ORS,\r\nOctober 26, 2017                                    6
# No-Admin Test Expedition 2\r\nPier 101,\r\nNove...                              NaN
# test 3\r\nPier 101,\r\nDecember 7, 2017                                           2
# Sub Zero\r\nIS 288 ORS,\r\nDecember 20, 2017                                      3
# Test for Maintenance\r\nBOP Test Station,\r\nDe...                              NaN
# SNOWYSTERS\r\nIS 288 ORS,\r\nFebruary 7, 2018                                     3

# %% [markdown]
# # Extract the values for each substrate shell for one expedition
# # Recall the expeditions are the rows so we use
# # *dataframe.iloc* to pass the index location (row number)
# # This will create an array of strings, each string contains the measurements
# # vals is of type numpy.ndarray, and each element of *vals* is a str

# %%
vals = data2018.iloc[0]["Measurements (mm)"].values

# %%
vals
# Out:
# array(['80,5.9', nan, '56', '64', nan, nan, '6.1', '64', '70', nan],
#       dtype=object)

# %% [markdown]
# # The cell above shows that vals is an array containing 'str' and nan

# %%
# what is the dtype for vals
type(vals)
# Out:
# numpy.ndarray

# %% [markdown]
# # We need to step through *vals* and break the items down

# %%
vals[0] # The first element is a 'str' of lenghth 6 containing 8-0-,5.9
# Out:
# '80,5.9'

# %%
len(vals[0])
# Out:
# 6

# %%
# what is the dtype for the first element of vals
# We see vals is a list of strings
type(vals[0])
# Out:
# str

# %%
vals # we see a mix of str and nan

# %%
type(vals[0].split(","))
# Out:
# list

# %% [markdown]
# # We can't do analysis yet because this is a list of str
# # We break out the individual values for the first string but each is still a str
# # And we have to deal with nan
# # If we try to split() a nan we get an error

# %%
print(vals[0])
vals[0].split(",")  # split breaks up the string '80,5.9' into two strings
# Out:
# 80,5.9
# ['80', '5.9']

# %%
# This throws an error because vals[1] is nan and nan's are floats not str
vals[1].split(",")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-47-12d7566481b6> in <module>()
#       1 # This throws an error because vals[1] is nan and nan's are floats not str
# ----> 2 vals[1].split(",")
#
# AttributeError: 'float' object has no attribute 'split'

# %%
# Pandas Series and DataFrames can use the dropna() method to remove nan's
pd.Series(vals).dropna()
# Out:
# 0    80,5.9
# 2        56
# 3        64
# 6       6.1
# 7        64
# 8        70
# dtype: object

# %%
# And to_numeric() converts strings to floats
pd.to_numeric(pd.Series(vals[0].split(",")))
# Out:
# 0    80.0
# 1     5.9
# dtype: float64

# %% [markdown]
# # The above code is the same as the following

# %%
a = vals[0].split(",")
b = pd.Series(a)
c = pd.to_numeric(b)
# let's see
print("a:", a, '\n', "b:", b, '\n', "c:", c)
# Out:
# a: ['80', '5.9']
#  b: 0     80
# 1    5.9
# dtype: object
#  c: 0    80.0
# 1     5.9
# dtype: float64

# %%
#Although b and c look the same
print(type(b[0]), '\n', type(c[0]))
# Out:
# <class 'str'>
#  <class 'numpy.float64'>

# %%
print(vals)
# Out:
# ['80,5.9' nan '56' '64' nan nan '6.1' '64' '70' nan]

# %%
for v in range(len(vals)):  # let's walk through the string array 
    if type(vals[v]) == str: # if the type is str then we can split() and make it a float
        print(pd.to_numeric(pd.Series(vals).dropna()[v].split(",")))
        # we can also print the mean for each substrate
        print('Substrate Shell #' + str(v+1) + ": \t The mean is ", 
              '%.3f' % pd.to_numeric(pd.Series(vals).dropna()[v].split(",")).mean(), sep='\t')
# Out:
# [80.   5.9]
# Substrate Shell #1: 	 The mean is 	42.950
# [56]
# Substrate Shell #3: 	 The mean is 	56.000
# [64]
# Substrate Shell #4: 	 The mean is 	64.000
# [6.1]
# Substrate Shell #7: 	 The mean is 	6.100
# [64]
# Substrate Shell #8: 	 The mean is 	64.000
# [70]
# Substrate Shell #9: 	 The mean is 	70.000

# %%
# Save the column name to a simple variable rather than retype this whole thing
wc = 'Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)'

# %%
print(wc)
# Out:
# Water color
# (1=Light Blue,2=Dark Blue,3=Light Green,
# 4=Dark Green,5=Light Brown,6=Dark Brown)

# %%
type(data2018)

# %%
data2018[["Measurements (mm)"]]

# %%
'''
Revised way of analyizing the data to get means by water color
***********************************************************
'''

# %%
# Extract measurements and water color only
df = data2018[["Measurements (mm)","Water color\r\n(1=Light Blue,2=Dark Blue,3=Light Green,\r\n4=Dark Green,5=Light Brown,6=Dark Brown)"]]
row, col = df.shape # get the dimensions of the dataframe

'''
Could add mangle_dupe_cols = True in read_csv and dupe col names will be col1, col2
'''
Wc = pd.Series(df.iloc[:,col-1]).astype(float) # Extract water colors and convert to float
y = pd.Series() # empty series

for r in range(row):
    x = pd.Series()
    for c in range(col-1):
        if type(df.iloc[r,c]) == str:
            h = pd.Series(df.iloc[r,c].split(",")).astype(float)
            for i in range(len(h)):
                if h.iloc[i] == 99999.0:  # some use 99999 as missing value
                    h = np.nan
            x = x.append(pd.Series(h))
        else:
            x = x.append(pd.Series(df.iloc[r,c]).astype(float))
    y = y.append(pd.Series(x.mean()))

WC = pd.DataFrame({'Water Color': Wc.values, 'Mean': y})
WC.groupby('Water Color').mean()

# %%
wc

# %%
# This stacks the measurements based on water color
v1 = np.array([])
v2 = np.array([])
v3 = np.array([])
v4 = np.array([])
v5 = np.array([])
v6 = np.array([])
for l in range(len(data2018["Measurements (mm)"].values)):
    # temp stores the observations for one expedition
    for t in range(10):
        if pd.notnull(data2018.iloc[l]['Measurements (mm)'].values[t]):
            w = np.array(data2018.iloc[l]["Measurements (mm)"].values[t].split(",")).astype(float)
            if data2018.iloc[l][wc] == '1':
                v1 = np.append(v1, w)
            elif data2018.iloc[l][wc] == '2':
                v2 = np.append(v2, w)
            elif data2018.iloc[l][wc] == '3':
                v3 = np.append(v3, w)
            elif data2018.iloc[l][wc] == '4':
                v4 = np.append(v4, w)
            elif data2018.iloc[l][wc] == '5':
                v5 = np.append(v5, w)
            else:
                v6 = np.append(v6, w)
        else:
            next

# %%
# Combine the measurements with water color into a new data frame
measures = np.concatenate((v1, v2, v3, v4, v5, v6), axis=0)
measures = pd.DataFrame({'Measures': measures})

measures['WaterColor'] = np.zeros(len(measures['Measures']))

# %%
ind = np.array([len(v1), len(v2), len(v3), len(v4),len(v5),len(v6)])
ind

cumind = np.cumsum(ind)

# %%
for i in range(cumind[0]):
    measures.loc[i, 'WaterColor'] = 1
for j in range(5):
    for i in range(cumind[j],cumind[j+1]):
        measures.loc[i, 'WaterColor'] = j+2

# %%
measures.head()
# Out:
#    Measures  WaterColor
# 0     105.0         1.0
# 1      88.0         1.0
# 2     115.0         1.0
# 3      70.0         2.0
# 4      60.0         2.0

# %%
#
measures.groupby("WaterColor").mean()
# Out:
#                 Measures
# WaterColor
# 1.0           102.666667
# 2.0            71.500000
# 3.0            13.686275
# 4.0          1051.761658
# 5.0            14.943979
# 6.0         17673.352941

# %%
# Some measurements are 99999 to indicate missing values! WHY???!!!
# So get rid of them; measures has all the data excluding those observations where 'Measures' is 99999
measures = measures[measures['Measures']!= 99999]
# measures['Measures']!= 99999

# %%
# Calculate the mean for each color
measures.groupby('WaterColor').mean()
# Out:
#               Measures
# WaterColor
# 1.0         102.666667
# 2.0          71.500000
# 3.0          13.686275
# 4.0          15.664921
# 5.0          14.943979
# 6.0          32.142857

# %%
measures.groupby('WaterColor').size()
# Out:
# WaterColor
# 1.0      3
# 2.0     24
# 3.0    204
# 4.0    191
# 5.0    191
# 6.0     14
# dtype: int64

# %%
measures['Measures'].plot.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
measures.groupby('WaterColor').mean().plot.bar(legend=None, title = "Mean by Water Color")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
measures.groupby('WaterColor').size().plot.bar()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
# In this example, I made up a second variable to plot against my measurements data
# I added random normal fluctuations to the measurements data (i.e., random noise)
measures['Measures + Noise'] = measures['Measures'] + np.random.normal(0,4,627)

# %%
measures.plot.scatter(y = 'Measures + Noise', x = 'Measures')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
measures['Measures'].plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
rn = np.array([[np.random.normal(0,1,100)],[np.random.normal(0.5,0.8,100)]])
plt.scatter(rn[0], rn[1])
plt.title('Zero Correlation')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
w = np.random.normal(0,1,100)
rn = np.array([w,w+2*np.random.normal(0,0.1,100)])
plt.scatter(rn[0], rn[1])
plt.title('Positive Correlation')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
w = np.random.normal(0,1,100)
rn = np.array([w, -w+3*np.random.normal(0.5,0.1,100)])
plt.scatter(rn[0], rn[1])
plt.title('Negative Correlation')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
measures['Measures'].plot.box()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
measures.head()

# %%
np.corrcoef(measures['Measures'], measures['Measures + Noise'])
# Out:
# array([[1.        , 0.97937819],
#        [0.97937819, 1.        ]])

# %%
# The p-value near zero indicates the correlation is statistically significant
rho, pstat = scipy.stats.pearsonr(measures['Measures'], measures['Measures + Noise'])
print('rho = %.4f' % rho, 'p-val = %.4f' % pstat)
# Out:
# rho = 0.9794 p-val = 0.0000

# %%
# We're testing the hypothesis that the two sample means are equal (statistically speaking)
tstat, pval = scipy.stats.ttest_ind(measures['Measures'], measures['Measures + Noise'])
print('t-stat = %.3f ' % tstat, 'p-value = %.3f' % pval)
# Out:
# t-stat = -0.215  p-value = 0.830

# %%
# Test if the mean measurements in two water colors are the same --- they're not; low p-value
tstat, pval = scipy.stats.ttest_ind(v1, v5)
print('t-stat = %.3f ' % tstat, 'p-value = %.3f' % pval)
# Out:
# t-stat = 12.106  p-value = 0.000

# %%
# If you want to test if there is a difference in the means from multiple groups
# use Analysis of Variance(ANOVA) 
fstat, pval = stats.f_oneway(v1, v3, v4, v5, v6)
print('ANOVA Results', 'fstat = %.3f' % fstat, 'p-value = %.3f' % pval, '\n', sep='\t')

# The null nypothesis for ANOVA is all means are equal
# If your test suggests rejecting the null you need to do a Tukey HSD comparison
# to see which pairs of means are different
from statsmodels.stats.multicomp import pairwise_tukeyhsd
print(pairwise_tukeyhsd(measures['Measures'], measures['WaterColor']))

# %%
# fixing the pH data issue for out of bounds data -- pH ranges from 0 to 14 
# note the original list is a list of str coming out of the BOP data
phs = pd.Series(['17.6', '8.2', '7.5'])
phsf = phs.astype(float)

# %%
phsf[phsf > 14.0] = np.nan
phsf
# Out:
# 0    NaN
# 1    8.2
# 2    7.5
# dtype: float64

# %%
phsf.mean()
# Out:
# 7.85

# %% [markdown]
# # HW exercise 88 -- Acme vs the Other Guys

# %%
data = {'X':[1,3,5,6,7,8,9,12,14,15,16,20,21,25], 'Y':[2,5,7,6,9,3,6,7,10,12,15,27,15,27]}

# %%
ddf = pd.DataFrame(data)

# %%
ddf
# Out:
#      X   Y
# 0    1   2
# 1    3   5
# 2    5   7
# 3    6   6
# 4    7   9
# 5    8   3
# 6    9   6
# 7   12   7
# 8   14  10
# 9   15  12
# 10  16  15
# 11  20  27
# 12  21  15
# 13  25  27

# %%
ddf.plot(x = 'X', y = 'Y', legend = None, title = "ACME Company")
axes = plt.gca()
axes.set_ylim([0,30])
axes.set_xlim([0,25])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 25)

# %%
ddf.plot(x = 'X', y = 'Y', legend=None, title = "Other Guys")
axes = plt.gca()
axes.set_ylim([0,200])
axes.set_xlim([0,25])
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0, 25)
